# %% [markdown]
# # Many Endings with different Image creation values
#
# ## Step 1.1
# ### Load nessecary modules

# %%
# Add python modules
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
from copy import deepcopy
# Add parent directory for custom modules
from sys import path as sysPath
sysPath.append('../')
sysPath.append('../Machine_Score/')

# Load custom modules that simr has loaded
import main_SIMR as SIMR
gm = SIMR.gm
im = SIMR.im
SIM = SIMR.SIM
IMG = SIMR.IMG
ms = SIMR.ms
sa = SIMR.sa
dc = SIMR.ms.dc

SIMR.test()
gm.test()
SIM.test()
IMG.test()
ms.test()
dc.test()
sa.test()
# Out:
# SIMR: Hi!  You're in Matthew's main program for all things galaxy collisions
# GM: Hi!  You're in Matthew's module for generally useful functions and classes
# SIM: Hi!  You're in Matthew's main code for all things simulation.
# IMG: Hi!  You're in Matthew's main code for all things image creation.
# MS: Hi!  You're in Matthew's SIMR module for all things machine scoring images
# DC: Hi!  You're in direct_image_compare.py
# SA: Hi!  You're in Matthew's Main program for score analysis!

# %% [markdown]
# ___
# ## Step 1.2
# ### Load Sample Target and Run Info class
# Needed for loading the target image and running through models later.

# %%
tDir = '../targetDir/'
#tDir = '../dataDir/588013383816904792/'
tDir = gm.validPath(tDir)

tInfo = im.target_info_class( targetDir = tDir, printAll=False)
if tInfo.status == False:
    print("WARNING: target info class bad")
else:
    print("Target Good!")
    
# Get run info class
rInfo = tInfo.getRunInfo( )

if rInfo.status == False:
    print("WARNING")
else:
    print("Run '%s' Good!"%rInfo.get('run_id'))
# Out:
# Target Good!
# Run 'run_0000' Good!

# %% [markdown]
# ___
# ## Step 2
# ### Load a starting image and image parameter for target
# Loading a previous image allows you to start with the correct image size and pixel centers for an associated target image.

# %%
if True: 
    # Change image name if you want to grab a different image parameter
    old_name = 'dl-s2-0'
    old_params = tInfo.getImageParams(  )
    old_param = old_params[old_name]

    # This image parameter should have the correct size and pixel centers
    # gm.pprint( old_param )

    # Grab mySet form param
    mySet = gm.readJson( '../param/mySet.json')
    # gm.pprint( mySet )

# %% [markdown]
# ___
# ## Step 2.1
# ### Create Base Score Parameters to modify

# %%
tid = tInfo.get('target_id')
print( tid )

if True: 
    c = 0
    bName = 'dl-s2-1-base' 
    baseParam = { bName : gm.deepcopy( tInfo.get('score_parameters')['dl-s2-0']) }
    baseParam[bName]['name'] = bName
    # baseParam[bName]['simArg']['type'] = 'many_endings'
    # baseParam[bName]['imgArg']['type'] = 'many_endings'
    baseParam[bName]['simArg']['nPts'] = '4k'
    baseParam[bName]['simArg']['name'] = '4k'
    # baseParam[bName]['simArg']['name'] = '4k-many-endings'
    baseParam[bName]['imgArg']['name'] = bName
    baseParam[bName]['imgArg']['radial_const'] = [1.0, 1.0]
    baseParam[bName]['imgArg']['blur']['size'] = 25
    baseParam[bName]['imgArg']['blur']['weight'] = 1
    baseParam[bName]['imgArg']['normalization']['type'] = 'type1'
    baseParam[bName]['imgArg']['normalization']['norm_constant'] = 1.5
    baseParam[bName]['imgArg']['radial_constant'] = -1


    cmdArgs = gm.inArgClass()
    cmdArgs.setArg( 'scoreParams', baseParam )
    cmdArgs.setArg( 'runInfo', rInfo )
    # cmdArgs.setArg( 'newSim', True )
    # cmdArgs.setArg( 'zipSim', True )
    cmdArgs.setArg( 'newImage', True )
    cmdArgs.setArg( 'overWrite', True )
    cmdArgs.setArg( 'printAll', True )

    SIMR.run_new_score( cmdArgs, rInfo )

    rInfo.printAll = True
    newImg = rInfo.getModelImage( bName )
    plt.imshow( newImg, cmap='gray' )
# Out:
# 587722984435351614
# SIMR.run_new_score:
# 	 - rDir: None
# 	 - rInfo: <class 'Support_Code.info_module.run_info_class'>
# SIMR.run_new_score:
# 	 - rInfo:  <Support_Code.info_module.run_info_class object at 0x7f25e3b445e0>
# 	 - runID: run_0000
# IMG: image_creator_run
# 	 - printAll
# IMG: given parameters: 1
# IMG:  dl-s2-1-base
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base
# IMG: Image 'dl-s2-1-base' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base_init.png
# IMG_LOOP:    1 /    1: COMPLETE
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base
# 	 - img type: model

# %% [markdown]
# ## 2.2 Create different Image Parameters for base model and init image

# %%
# Image Parameter values and ranges for np.linspace
mySet[tid]['blur-weight-range'] = [ 0.7, 1.8, 3 ]
mySet[tid]['norm-types'] = [ 'type1' ]
mySet[tid]['norm-range'] = [ 1.5, 2.5, 3 ]
mySet[tid]['radial-range'] = [ -1.5, 1, 3 ]


rBlur = mySet[tid]['blur-weight-range']
rNorm = mySet[tid]['norm-range']
rRadial = mySet[tid]['radial-range']

# Create Base Model and Initial Parameters

newParams = {}
c = 0
for w in np.linspace( rBlur[0], rBlur[1], rBlur[2] ):
    for n in np.linspace( rNorm[0], rNorm[1], rNorm[2] ):
        for r1 in np.linspace( rRadial[0], rRadial[1], rRadial[2] ):
            tempName = 'dl-s2-1-base-%d' % c
            newParams[tempName] = gm.deepcopy( baseParam[bName] )
            newParams[tempName]['name'] = tempName
            newParams[tempName]['imgArg']['name'] = tempName
            imgArg = newParams[tempName]['imgArg']
            imgArg['blur']['weight'] = w
            imgArg['normalization']['norm_constant'] = n
            imgArg['radial_const'] = [ r1, r1 ]
            print( 'c: ', c, 'w: ', w, 'n: ', n, 'r1: ', r1,)
            c += 1

manyBase = 'dl-s2-1-many-0' 
newParams[manyBase] = gm.deepcopy( tInfo.get('score_parameters')['dl-s2-0'] )
newParams[manyBase]['name'] = manyBase
newParams[manyBase]['simArg']['type'] = 'many_endings'
newParams[manyBase]['imgArg']['type'] = 'many_endings'
newParams[manyBase]['simArg']['nPts'] = '4k'
newParams[manyBase]['simArg']['name'] = '4k-many-endings'
newParams[manyBase]['imgArg']['name'] = manyBase
newParams[manyBase]['imgArg']['blur']['size'] = 25
newParams[manyBase]['imgArg']['blur']['weight'] = mySet[tid]['blur-weight-range'][0]
newParams[manyBase]['imgArg']['normalization']['type'] = mySet[tid]['norm-types'][0]
newParams[manyBase]['imgArg']['normalization']['norm_constant'] = mySet[tid]['norm-range'][0]
newParams[manyBase]['imgArg']['radial_const'] = [ mySet[tid]['radial-range'][0], mySet[tid]['radial-range'][0]]


# Create Many Parameters
c = 0
for w in np.linspace( rBlur[0], rBlur[1], rBlur[2] ):
    for n in np.linspace( rNorm[0], rNorm[1], rNorm[2] ):
        for r1 in np.linspace( rRadial[0], rRadial[1], rRadial[2] ):
            tempName = 'dl-s2-1-many-%d'  % c
            newParams[tempName] = gm.deepcopy( newParams[manyBase] )
            newParams[tempName]['name'] = tempName
            newParams[tempName]['imgArg']['name'] = tempName
            imgArg = newParams[tempName]['imgArg']
            imgArg['blur']['weight'] = w
            imgArg['normalization']['norm_constant'] = n
            imgArg['radial_const'] = [ r1, r1 ]
            print( 'c: ', c, 'w: ', w, 'n: ', n, 'r1: ', r1,)
            c += 1

if True:
    cmdArgs = gm.inArgClass()
    cmdArgs.setArg( 'scoreParams', newParams )
    cmdArgs.setArg( 'runInfo', rInfo )
    # cmdArgs.setArg( 'newSim', True )
    # cmdArgs.setArg( 'zipSim', True )
    cmdArgs.setArg( 'newImage', True )
    cmdArgs.setArg( 'overWrite', True )
    cmdArgs.setArg( 'printAll', True )

    rInfo.printAll = True
    SIMR.run_new_score( cmdArgs, rInfo )
# Out:
# c:  0 w:  0.7 n:  1.5 r1:  -1.5
# c:  1 w:  0.7 n:  1.5 r1:  -0.25
# c:  2 w:  0.7 n:  1.5 r1:  1.0
# c:  3 w:  0.7 n:  2.0 r1:  -1.5
# c:  4 w:  0.7 n:  2.0 r1:  -0.25
# c:  5 w:  0.7 n:  2.0 r1:  1.0
# c:  6 w:  0.7 n:  2.5 r1:  -1.5
# c:  7 w:  0.7 n:  2.5 r1:  -0.25
# c:  8 w:  0.7 n:  2.5 r1:  1.0
# c:  9 w:  1.25 n:  1.5 r1:  -1.5
# c:  10 w:  1.25 n:  1.5 r1:  -0.25
# c:  11 w:  1.25 n:  1.5 r1:  1.0
# c:  12 w:  1.25 n:  2.0 r1:  -1.5
# c:  13 w:  1.25 n:  2.0 r1:  -0.25
# c:  14 w:  1.25 n:  2.0 r1:  1.0
# c:  15 w:  1.25 n:  2.5 r1:  -1.5
# c:  16 w:  1.25 n:  2.5 r1:  -0.25
# c:  17 w:  1.25 n:  2.5 r1:  1.0
# c:  18 w:  1.8 n:  1.5 r1:  -1.5
# c:  19 w:  1.8 n:  1.5 r1:  -0.25
# c:  20 w:  1.8 n:  1.5 r1:  1.0
# c:  21 w:  1.8 n:  2.0 r1:  -1.5
# c:  22 w:  1.8 n:  2.0 r1:  -0.25
# c:  23 w:  1.8 n:  2.0 r1:  1.0
# c:  24 w:  1.8 n:  2.5 r1:  -1.5
# c:  25 w:  1.8 n:  2.5 r1:  -0.25
# c:  26 w:  1.8 n:  2.5 r1:  1.0
# c:  0 w:  0.7 n:  1.5 r1:  -1.5
# c:  1 w:  0.7 n:  1.5 r1:  -0.25
# c:  2 w:  0.7 n:  1.5 r1:  1.0
# c:  3 w:  0.7 n:  2.0 r1:  -1.5
# c:  4 w:  0.7 n:  2.0 r1:  -0.25
# c:  5 w:  0.7 n:  2.0 r1:  1.0
# c:  6 w:  0.7 n:  2.5 r1:  -1.5
# c:  7 w:  0.7 n:  2.5 r1:  -0.25
# c:  8 w:  0.7 n:  2.5 r1:  1.0
# c:  9 w:  1.25 n:  1.5 r1:  -1.5
# c:  10 w:  1.25 n:  1.5 r1:  -0.25
# c:  11 w:  1.25 n:  1.5 r1:  1.0
# c:  12 w:  1.25 n:  2.0 r1:  -1.5
# c:  13 w:  1.25 n:  2.0 r1:  -0.25
# c:  14 w:  1.25 n:  2.0 r1:  1.0
# c:  15 w:  1.25 n:  2.5 r1:  -1.5
# c:  16 w:  1.25 n:  2.5 r1:  -0.25
# c:  17 w:  1.25 n:  2.5 r1:  1.0
# c:  18 w:  1.8 n:  1.5 r1:  -1.5
# c:  19 w:  1.8 n:  1.5 r1:  -0.25
# c:  20 w:  1.8 n:  1.5 r1:  1.0
# c:  21 w:  1.8 n:  2.0 r1:  -1.5
# c:  22 w:  1.8 n:  2.0 r1:  -0.25
# c:  23 w:  1.8 n:  2.0 r1:  1.0
# c:  24 w:  1.8 n:  2.5 r1:  -1.5
# c:  25 w:  1.8 n:  2.5 r1:  -0.25
# c:  26 w:  1.8 n:  2.5 r1:  1.0
# SIMR.run_new_score:
# 	 - rDir: None
# 	 - rInfo: <class 'Support_Code.info_module.run_info_class'>
# SIMR.run_new_score:
# 	 - rInfo:  <Support_Code.info_module.run_info_class object at 0x7f25e3b445e0>
# 	 - runID: run_0000
# 	 - Overwriting old scores
# 	 - Creating new scores
# IMG: image_creator_run
# 	 - printAll
# IMG: given parameters: 54
# IMG:  dl-s2-1-base-0
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-0
# IMG: Image 'dl-s2-1-base-0' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-0_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-0_init.png
# IMG:  dl-s2-1-base-14
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-1
# IMG: Image 'dl-s2-1-base-1' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-1_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-1_init.png
# IMG:  dl-s2-1-base-24
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-2
# IMG: Image 'dl-s2-1-base-2' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-2_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-2_init.png
# IMG:  dl-s2-1-base-34
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-3
# IMG: Image 'dl-s2-1-base-3' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-3_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-3_init.png
# IMG:  dl-s2-1-base-44
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-4
# IMG: Image 'dl-s2-1-base-4' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-4_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-4_init.png
# IMG:  dl-s2-1-base-54
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-5
# IMG: Image 'dl-s2-1-base-5' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-5_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-5_init.png
# IMG:  dl-s2-1-base-64
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-6
# IMG: Image 'dl-s2-1-base-6' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-6_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-6_init.png
# IMG:  dl-s2-1-base-74
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-7
# IMG: Image 'dl-s2-1-base-7' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-7_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-7_init.png
# IMG:  dl-s2-1-base-84
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-8
# IMG: Image 'dl-s2-1-base-8' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-8_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-8_init.png
# IMG:  dl-s2-1-base-94
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-9
# IMG: Image 'dl-s2-1-base-9' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-9_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-9_init.png
# IMG:  dl-s2-1-base-10
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-10
# IMG: Image 'dl-s2-1-base-10' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-10_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-10_init.png
# IMG:  dl-s2-1-base-11
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-11
# IMG: Image 'dl-s2-1-base-11' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-11_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-11_init.png
# IMG:  dl-s2-1-base-12
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-12
# IMG: Image 'dl-s2-1-base-12' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-12_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-12_init.png
# IMG:  dl-s2-1-base-13
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-13
# IMG: Image 'dl-s2-1-base-13' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-13_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-13_init.png
# IMG:  dl-s2-1-base-14
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-14
# IMG: Image 'dl-s2-1-base-14' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-14_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-14_init.png
# IMG:  dl-s2-1-base-15
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-15
# IMG: Image 'dl-s2-1-base-15' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-15_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-15_init.png
# IMG:  dl-s2-1-base-16
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-16
# IMG: Image 'dl-s2-1-base-16' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-16_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-16_init.png
# IMG:  dl-s2-1-base-17
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-17
# IMG: Image 'dl-s2-1-base-17' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-17_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-17_init.png
# IMG:  dl-s2-1-base-18
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-18
# IMG: Image 'dl-s2-1-base-18' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-18_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-18_init.png
# IMG:  dl-s2-1-base-19
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-19
# IMG: Image 'dl-s2-1-base-19' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-19_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-19_init.png
# IMG:  dl-s2-1-base-20
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-20
# IMG: Image 'dl-s2-1-base-20' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-20_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-20_init.png
# IMG:  dl-s2-1-base-21
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-21
# IMG: Image 'dl-s2-1-base-21' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-21_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-21_init.png
# IMG:  dl-s2-1-base-22
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-22
# IMG: Image 'dl-s2-1-base-22' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-22_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-22_init.png
# IMG:  dl-s2-1-base-23
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-23
# IMG: Image 'dl-s2-1-base-23' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-23_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-23_init.png
# IMG:  dl-s2-1-base-24
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-24
# IMG: Image 'dl-s2-1-base-24' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-24_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-24_init.png
# IMG:  dl-s2-1-base-25
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-25
# IMG: Image 'dl-s2-1-base-25' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-25_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-25_init.png
# IMG:  dl-s2-1-base-26
# IMG: create_basic_run_image:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-base-26
# IMG: Image 'dl-s2-1-base-26' already made for run_0000
# IMG: getBasicRunParticles:
# 	 - simArg: <class 'dict'>
# 	 - Creating image from points
# 	 - Saving model image at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/model_images/dl-s2-1-base-26_model.png
# 	 - Saving unperturbed at: /home/jovyan/galStuff/spam-data-2022-11/587722984435351614/zoo_merger_models/run_0000/misc_images/dl-s2-1-base-26_init.png
# IMG:  dl-s2-1-many-04
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-0
# 	 - Creating image: dl-s2-1-many-0
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-14
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-1
# 	 - Creating image: dl-s2-1-many-1
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-24
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-2
# 	 - Creating image: dl-s2-1-many-2
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-34
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-3
# 	 - Creating image: dl-s2-1-many-3
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-44
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-4
# 	 - Creating image: dl-s2-1-many-4
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-54
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-5
# 	 - Creating image: dl-s2-1-many-5
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-64
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-6
# 	 - Creating image: dl-s2-1-many-6
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-74
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-7
# 	 - Creating image: dl-s2-1-many-7
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-84
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-8
# 	 - Creating image: dl-s2-1-many-8
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-94
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-9
# 	 - Creating image: dl-s2-1-many-9
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-10
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-10
# 	 - Creating image: dl-s2-1-many-10
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-11
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-11
# 	 - Creating image: dl-s2-1-many-11
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-12
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-12
# 	 - Creating image: dl-s2-1-many-12
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-13
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-13
# 	 - Creating image: dl-s2-1-many-13
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-14
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-14
# 	 - Creating image: dl-s2-1-many-14
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-15
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-15
# 	 - Creating image: dl-s2-1-many-15
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-16
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-16
# 	 - Creating image: dl-s2-1-many-16
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-17
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-17
# 	 - Creating image: dl-s2-1-many-17
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-18
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-18
# 	 - Creating image: dl-s2-1-many-18
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-19
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-19
# 	 - Creating image: dl-s2-1-many-19
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-20
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-20
# 	 - Creating image: dl-s2-1-many-20
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-21
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-21
# 	 - Creating image: dl-s2-1-many-21
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-22
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-22
# 	 - Creating image: dl-s2-1-many-22
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-23
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-23
# 	 - Creating image: dl-s2-1-many-23
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-24
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-24
# 	 - Creating image: dl-s2-1-many-24
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-25
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-25
# 	 - Creating image: dl-s2-1-many-25
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG:  dl-s2-1-many-26
# IMG: create_many_endings_images:
# 	 - runId: run_0000
# 	 - score: dl-s2-1-many-26
# 	 - Creating image: dl-s2-1-many-26
# IMG: getManyParticles:
# 	 - simArg: <class 'str'>
# manyImg shape:  (11, 128, 128)
# IMG_LOOP:   54 /   54: COMPLETE

# %%
if True:

    # Get images
    imgList = []
    for imgName in newParams: 
        print( imgName )
        if 'base' in imgName:
            newImg1 = rInfo.getModelImage( imgName, imgType='model' )
            newImg2 = rInfo.getModelImage( imgName, imgType='init' )
            print( 'baseMaxes: ', np.amax( newImg1 ), np.amax( newImg2 ) )

            imgList.append( newImg1 )
            imgList.append( newImg2 )
    gm.showImgList( imgList, size=18, col_count=4 )
# Out:
# dl-s2-1-base-0
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-0
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-0
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-1
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-1
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-1
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-2
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-2
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-2
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-3
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-3
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-3
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-4
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-4
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-4
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-5
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-5
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-5
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-6
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-6
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-6
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-7
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-7
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-7
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-8
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-8
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-8
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-9
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-9
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-9
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-10
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-10
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-10
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-11
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-11
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-11
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-12
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-12
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-12
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-13
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-13
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-13
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-14
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-14
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-14
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-15
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-15
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-15
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-16
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-16
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-16
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-17
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-17
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-17
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-18
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-18
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-18
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-19
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-19
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-19
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-20
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-20
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-20
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-21
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-21
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-21
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-22
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-22
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-22
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-23
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-23
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-23
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-24
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-24
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-24
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-25
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-25
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-25
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-base-26
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-26
# 	 - img type: model
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-base-26
# 	 - img type: init
# baseMaxes:  1.0 1.0
# dl-s2-1-many-0
# dl-s2-1-many-1
# dl-s2-1-many-2
# dl-s2-1-many-3
# dl-s2-1-many-4
# dl-s2-1-many-5
# dl-s2-1-many-6
# dl-s2-1-many-7
# dl-s2-1-many-8
# dl-s2-1-many-9
# dl-s2-1-many-10
# dl-s2-1-many-11
# dl-s2-1-many-12
# dl-s2-1-many-13
# dl-s2-1-many-14
# dl-s2-1-many-15
# dl-s2-1-many-16
# dl-s2-1-many-17
# dl-s2-1-many-18
# dl-s2-1-many-19
# dl-s2-1-many-20
# dl-s2-1-many-21
# dl-s2-1-many-22
# dl-s2-1-many-23
# dl-s2-1-many-24
# dl-s2-1-many-25
# dl-s2-1-many-26

# %%
if True:

    # Get images
    imgList = []
    for imgName in newParams: 
        print( imgName )
        if 'many' in imgName:
            newImgList = rInfo.getModelImage( imgName, imgType='many_endings' )
            for newImg in newImgList:
                imgList.append( newImg )
            break
            

    gm.showImgList( imgList, size=18, col_count=3 )
# Out:
# dl-s2-1-base-0
# dl-s2-1-base-1
# dl-s2-1-base-2
# dl-s2-1-base-3
# dl-s2-1-base-4
# dl-s2-1-base-5
# dl-s2-1-base-6
# dl-s2-1-base-7
# dl-s2-1-base-8
# dl-s2-1-base-9
# dl-s2-1-base-10
# dl-s2-1-base-11
# dl-s2-1-base-12
# dl-s2-1-base-13
# dl-s2-1-base-14
# dl-s2-1-base-15
# dl-s2-1-base-16
# dl-s2-1-base-17
# dl-s2-1-base-18
# dl-s2-1-base-19
# dl-s2-1-base-20
# dl-s2-1-base-21
# dl-s2-1-base-22
# dl-s2-1-base-23
# dl-s2-1-base-24
# dl-s2-1-base-25
# dl-s2-1-base-26
# dl-s2-1-many-0
# IM.run_info_class.getModelImage:
# 	 - img name: dl-s2-1-many-0
# 	 - img type: many_endings

# %%
tInfo.addImageParams( newParams )
tInfo.saveScoreParam( newParams, 'dl-s2-1' )
tInfo.saveInfoFile()
