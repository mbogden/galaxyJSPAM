# %%
# Add parent directory
from sys import path as sysPath
sysPath.append('../')

# Add custom modules
from Support_Code import general_module as gm
from Support_Code import info_module as im
from Image_Creator import main_image_creator as ic
from Score_Analysis import main_score_analysis as sa

sysPath.append('../Machine_Score/')
from Machine_Score import main_machine_score as ms
import main_SIMR as simr


# General modules
from os import path
import numpy as np
from matplotlib import pyplot as plt

if 'Machine_Compare' not in sysPath:
    sysPath.append('Machine_Compare')

from Image_Creator import main_image_creator as ic
import main_SIMR as simr

sa.test()
gm.test()
im.test()
ic.test()
ms.test()
simr.test()
# Out:
# SA: Hi!  You're in Matthew's Main program for score analysis!
# GM: Hi!  You're in Matthew's module for generally useful functions and classes
# IM: Hi!  You're in Matthew Ogden's information module for SPAM
# IC: Hi!  You're in Matthew's main code for all things image creation.
# MS: Hi!  You're in Matthew's SIMR module for all things machine scoring images
# SIMR: Hi!  You're in Matthew's main program for all things galaxy collisions

# %%
tDir = '/home/mbo2d/galStuff/spam_data_pl3/587722984435351614/' 
tInfo = im.target_info_class( targetDir = tDir, printAll=False)

scores = tInfo.getScores()
print(scores)

rId = '00001'
rInfo = tInfo.getRunInfo(rID=rId, printAll = False)
rInfo.link_tInfo = tInfo
print(rInfo.status)
# Out:
#       run_id  zoo_merger_score   test_v0  test_perturbation
# 0     r00000          0.945946  0.839341           0.798118
# 1     r00001          0.941176  0.737633           0.716723
# 2     r00002          0.918919  0.793071           0.713520
# 3     r00003          0.916667  0.764586           0.689120
# 4     r00004          0.916667  0.730096                NaN
# ...      ...               ...       ...                ...
# 1288  r01288          0.000000  0.797219           0.954986
# 1289  r01289          0.000000  0.775788           0.992380
# 1290  r01290          0.000000  0.831271           0.993772
# 1291  r01291          0.000000  0.818303           0.948159
# 1292  r01292          0.000000  0.840964           0.976869
#
# [1293 rows x 4 columns]
# True

# %%
tInfo.gatherRunInfos()
print(tInfo.getScores())
# Out:
# Process-5 - queue empty - 3 / 1293		  0.3% - 4 / 1293		  1.7% - 22 / 1293		  1.8% - 23 / 1293		  2.6% - 33 / 1293		  2.6% - 34 / 1293		  4.0% - 52 / 1293		  4.1% - 53 / 1293		  4.7% - 61 / 1293		  4.8% - 62 / 1293		  11.1% - 144 / 1293		  11.2% - 145 / 1293		  11.4% - 147 / 1293		  11.4% - 148 / 1293		  12.2% - 158 / 1293		  12.3% - 159 / 1293		  13.5% - 175 / 1293		  13.6% - 176 / 1293		  14.2% - 183 / 1293		  14.2% - 184 / 1293		  14.8% - 192 / 1293		  14.9% - 193 / 1293		  15.8% - 204 / 1293		  15.9% - 205 / 1293		  20.9% - 270 / 1293		  21.0% - 271 / 1293		  21.3% - 275 / 1293		  21.3% - 276 / 1293		  22.0% - 284 / 1293		  22.0% - 285 / 1293		  22.2% - 287 / 1293		  22.3% - 288 / 1293		  25.8% - 334 / 1293		  25.9% - 335 / 1293		  26.1% - 338 / 1293		  26.2% - 339 / 1293		  26.4% - 341 / 1293		  26.5% - 342 / 1293		  28.4% - 367 / 1293		  28.5% - 369 / 1293		  29.3% - 379 / 1293		  29.4% - 380 / 1293		  30.5% - 394 / 1293		  30.5% - 395 / 1293		  30.7% - 397 / 1293		  30.8% - 398
# ...

# %%
tInfo.updateScores()
print(tInfo.getScores())
# Out:
# {'machine_scores': {'run_id': 1293, 'test_v0': 1293, 'test_perturbation': 1289, 'base0_corr': 1, 'base0_diff': 1, 'base0_diff_scale': 1, 'base0_overlap0': 1, 'base0_bcorr0': 1, 'base0_diff_scale1': 1, 'base0_overlap1': 1, 'base0_overlap2': 1, 'base0_overlap3': 1, 'base0_bcorr1': 1, 'base0_bcorr2': 1, 'base0_bcorr3': 1, 'base0_diff_scale2': 1}}
#       run_id  zoo_merger_score   test_v0  test_perturbation  base0_corr  \
# 0     r00000          0.945946  0.839341           0.798118         NaN
# 1     r00001          0.941176  0.737633           0.716723    0.737633
# 2     r00002          0.918919  0.793071           0.713520         NaN
# 3     r00003          0.916667  0.764586           0.689120         NaN
# 4     r00004          0.916667  0.730096                NaN         NaN
# ...      ...               ...       ...                ...         ...
# 1288  r01288          0.000000  0.797219           0.954986         NaN
# ...

# %%
tLoc = tInfo.findTargetImage( 'zoo' )
print(tLoc)
# Out:
# /mnt/c/Users/ogden/OneDrive/Desktop/galStuff/spam_data_pl3/587722984435351614/information/target_zoo.png

# %%
import cv2
tImg = gm.readImg(tLoc)
tImg2 = tImg[400:700,150:650]
#output = cv2.resize(src, dsize)
tImg3 = cv2.resize( tImg2, (64,64) )
plt.imshow(tImg3)

# %%
import cv2 as cv
img = tImg3

sobelx = cv.Sobel(img,cv.CV_64F,1,0,ksize=5)
sobely = cv.Sobel(img,cv.CV_64F,0,1,ksize=5)

laplacian = cv.Laplacian(img,cv.CV_64F)


plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')

plt.title('Original'), plt.xticks([]), plt.yticks([])
#plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.subplot(2,2,2),plt.imshow( np.sqrt(sobelx**2 + sobely**2) ,cmap = 'gray')

#b=cv2.normalize(a,dst,0,255,cv2.NORM_L1)
direction = np.arctan2( sobelx, sobely )
print( np.histogram(direction) )

#cv.normalize( , direction, 0, 255, cv.NORM_L1 )
#plt.subplot(2,2,2),plt.imshow( direction  ,cmap = 'gray')


plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# (array([ 152,  191,  320,  192, 2104,  181,  235,  262,  204,  255]), array([-3.13526362, -2.507578  , -1.87989237, -1.25220674, -0.62452111,
#         0.00316451,  0.63085014,  1.25853577,  1.8862214 ,  2.51390703,
#         3.14159265]))

# %%
imgLoc1 = '../spam_data_pl3/587722984435351614/gen000/run_00000/model_images/wndcharm_17_model.png'
imgLoc2 = '../spam_data_pl3/587722984435351614/gen000/run_00000/misc_images/default_init.png'

img1 = gm.readImg(imgLoc2)
img2 = img1[400:800,200:600]
plt.imshow(img2)

# %%
import cv2 as cv
img = img2

sobelx = cv.Sobel(img,cv.CV_64F,1,0,ksize=5)
sobely = cv.Sobel(img,cv.CV_64F,0,1,ksize=5)

laplacian = cv.Laplacian(img,cv.CV_64F)


plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')

plt.title('Original'), plt.xticks([]), plt.yticks([])
#plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.subplot(2,2,2),plt.imshow( np.sqrt(sobelx**2 + sobely**2) ,cmap = 'gray')

#b=cv2.normalize(a,dst,0,255,cv2.NORM_L1)
direction = np.arctan2( sobelx, sobely )
print( np.histogram(direction) )

#cv.normalize( , direction, 0, 255, cv.NORM_L1 )
#plt.subplot(2,2,2),plt.imshow( direction  ,cmap = 'gray')


plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# (array([  3936,   4046,   3697,   4276, 120876,   4505,   4936,   4745,
#          4936,   4047]), array([-3.13947551e+00, -2.51136869e+00, -1.88326188e+00, -1.25515506e+00,
#        -6.27048243e-01,  1.05857287e-03,  6.29165389e-01,  1.25727221e+00,
#         1.88537902e+00,  2.51348584e+00,  3.14159265e+00]))

# %%
p1 = im.score_parameter_class( paramLoc = 'param/t0.json' )
p2 = im.score_parameter_class( paramLoc = 'param/t1.json' )

print(p1.status, p2.status)
# Out:
# IM: score_param_class.__init__
# 	 - paramLoc:  param/t0.json
# 	 - paramDict:  <class 'NoneType'>
# IM: score_param_class.__init__
# 	 - paramLoc:  param/t1.json
# 	 - paramDict:  <class 'NoneType'>
# True True

# %%
baseParam = im.group_score_parameter_class()
baseParam.addParam( p1 )
baseParam.addParam( p2 )
baseParam.printGroup( )
baseParam.saveParam(saveLoc='param/base_param.json')
# Out:
# {'base_score': {'name': 'base_score', 'simArg': {'name': '100k', 'nPts': '100k'}, 'imgArg': {'name': 'default', 'pType': 'default'}, 'scoreType': 'target', 'targetName': 'zoo', 'cmpArg': {'cmpMethod': 'correlation'}}, 'base_perturbation': {'name': 'base_perturbation', 'simArg': {'name': '100k', 'nPts': '100k'}, 'imgArg': {'name': 'default', 'pType': 'default'}, 'scoreType': 'perturbation', 'cmpArg': {'cmpMethod': 'correlation'}}}

# %%
#print( tInfo.get('score_parameters'))
pall2 = group_param()
pall2.addDict( tInfo.get('score_parameters') ) 
pall2.printGroup()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-45263aeb18a2> in <module>
#       1 #print( tInfo.get('score_parameters'))
# ----> 2 pall2 = group_param()
#       3 pall2.addDict( tInfo.get('score_parameters') )
#       4 pall2.printGroup()
#
# NameError: name 'group_param' is not defined

# %%
def createRunScores( rInfo = None, pGroup = None, \
        printBase = True, printAll = False, \
        tList = None, ):

    # Create new score if variable is given
    if printBase: print("SIMR: createRunScores")
        
    if rInfo == None or pGroup == None or len(pGroup.group) == 0:
        if printBase: 
            print("SIMR: createRunScores: WARNING")

            
        return None
    
    pClass = None        
    
    for pName in pGroup.group:
        print(pName, rInfo.status)
        
        if pClass == None:
            pClass = im.score_parameter_class( paramDict = pGroup.get(pName) )
        else:
            pClass.setDict( pGroup.get(pName) )

        mcVal = mc.pipelineRun( printBase = printBase, printAll = printAll, \
            rInfo = rInfo, pClass = pClass, )
        mcVal = mc.pipelineRun( printBase = printBase, printAll = True, \
            rInfo = rInfo, pClass = pClass, )
    
        print(mcVal)
    
# end processing run

rInfo = im.run_info_class( runDir = '../runEx/', newInfo = True, printAll = True)
print("rInfo.status: ", rInfo.status)
rInfo.printInfo()

if rInfo.status:
    createRunScores( rInfo = rInfo, pGroup = pall2 )

# %%
def createTargetScores( tInfo, pClass, printBase = True, printAll = False, nonScores = None ):

    if printBase:
        print("SIMR: newTargetScores:")
        print("\t - tInfo: %s" % tInfo.status )
        print("\t - pClass: %s" % pClass.status )

    if pClass.status == False:
        if printBase: print("SIMR: Please provice valid pClass to create new scores")
        return
    
    sName = pClass.get('name')

    # Check if new scores are needed
    pDict = tInfo.tDict['progress']
    nRuns = pDict['zoo_merger_models']

    # Start fresh or appending?
    count, total = tInfo.getScoreCount( scrName = sName )
    if count == 0:
        tInfo.addScoreParam( pClass )
    
    # Initialize score creation 
    cmpType = pClass.get('cmpType',None)

    # Get target image
    if cmpType == 'target':
        tLoc = tInfo.findTargetImage( tName = pClass.get('targetName', None) )
        tImg = mc.getImg( tLoc )
        if type(tImg) == type(None):
            print("SIMR: newTargetScores: ERROR:")
            print("\t - Failed to read target img")
            print("\t - targetName: %s" % tName )

    elif cmpType == 'perturbation':
        tImg = None
        tLoc = None

    scores = tInfo.getScores()

    for i, row in scores.iterrows():

        rID = row['run_id']
        score = row[sName]

        if pd.isnull( row[sName] ):

            rInfo = tInfo.getRunInfo( rID = rID, printBase = printAll )
            score = mc.pipelineRun( rInfo = rInfo, pClass = pClass, \
                    tImg = tImg, printBase = printAll, )

            tInfo.addScore( rID, sName, score )

        if printBase:
            print(" New Scores: %d / %d" % ( i, nRuns ), end='\r' )
        
        if i > 15:
            break

    tInfo.updateScoreProg()
    tInfo.saveInfoFile()


# End processing target dir
